# %% [markdown]
# ### Q1

# %% [markdown]
# ### Q2
# OPENQASM 2.0;
# include "qelib1.inc";
#
# qreg q[3];
# creg c[3];
#
# x q[0];
# x q[1];
# x q[2];
#
# measure q[0] -> c[0];
# measure q[1] -> c[1];
# measure q[2] -> c[2];

# %% [markdown]
# ### Q3
#
# OPENQASM 2.0;
# include "qelib1.inc";
#
#
# qreg q[3];
#
#
# creg c[3];
#
# x q[0];
# h q[1];
# x q[2];
#
#
# measure q[2] -> c[2];
# measure q[1] -> c[1];
# measure q[0] -> c[0];

# %% [markdown]
# ### Q4
#
# OPENQASM 2.0;
# include "qelib1.inc";
#
#
# qreg q[3];
#
#
# creg c[3];
#
# h q[1];
# h q[2];
# h q[0];

# %% [markdown]
# ### Q5
#
# OPENQASM 2.0;
#
# include "qelib1.inc";
#
# qreg q[2];
# creg c[2];
#
#
# h q[1];
# cx q[1], q[0];
# x q[0];

# %% [markdown]
# ### Q6
#
# OPENQASM 2.0;
#
# include "qelib1.inc";
#
# qreg q[1];
# creg c[2];
#
#
# h q[0];

# %% [markdown]
# OPENQASM 2.0;
# include "qelib1.inc";
#
#
# qreg q[2];
#
#
# creg c[1];
# x q[0];
# x q[1];
# h q[0];
# h q[1];
# h q[0];
# h q[1];
# measure q[0] -> c[0];
